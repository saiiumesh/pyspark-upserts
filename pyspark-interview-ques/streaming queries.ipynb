# %% [markdown]
# **_streaming queries i/p_**

# %%
my_schema = """order_id STRING,
               customer_id STRING,
               order_date TIMESTAMP,
               AMOUNT FLOAT """

# %%
df_batch = spark.read.format('csv')\
  .option("header", "true")\
  .option("checkpointLocation", "/Volumes/pyspark_data/source/dbvolume/streamsource/checkpoint")\
  .schema(my_schema)\
  .load("/Volumes/pyspark_data/source/dbvolume/streamsource/")

display(df_batch)

# %% [markdown]
# **_loading stream output_**

# %%
df.writeStream\
  .format("delta")\
  .option("checkpointLocation", "/Volumes/pyspark_data/source/dbvolume/streamsink/checkpoint")\
  .option("mergeSchema", "true")\
  .trigger(once=True)\
  .start("/Volumes/pyspark_data/source/dbvolume/streamsink/delta")

# %%
# %sql
select * from delta.`/Volumes/pyspark_data/source/dbvolume/streamsink/delta/`
